# %%
import pandas as pd
from sqlalchemy import create_engine, text
from utils.utils import build_db_url

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
engine = create_engine(build_db_url())

# %%
df = pd.read_parquet('data\statcast_pitching_lad_2025-03-18_2025-11-01_f008ac3a-0f27-4843-b345-95059ed956bf.parquet')

# %%
df.dtypes
# Out:
# pitch_type                                   object
# game_date                                    object
# release_speed                               float64
# release_pos_x                               float64
# release_pos_z                               float64
# player_name                                  object
# batter                                        int64
# pitcher                                       int64
# events                                       object
# description                                  object
# spin_dir                                    float64
# spin_rate_deprecated                        float64
# break_angle_deprecated                      float64
# break_length_deprecated                     float64
# zone                                        float64
# des                                          object
# game_type                                    object
# stand                                        object
# ...

# %%
df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SI  2025-11-01           97.0          -1.45           5.94
# 1         SL  2025-11-01           88.9          -1.44           5.97
# 2         SI  2025-11-01           97.6          -1.44           5.90
# 3         FF  2025-11-01           97.4          -1.31           5.94
# 4         FF  2025-11-01           96.8          -1.26           6.01
#
#       player_name  batter  pitcher     events      description  spin_dir  \
# 0  Glasnow, Tyler  665489   607192  field_out    hit_into_play       NaN
# 1  Glasnow, Tyler  665489   607192       None             ball       NaN
# 2  Glasnow, Tyler  664770   607192  field_out    hit_into_play       NaN
# 3  Glasnow, Tyler  664770   607192       None    called_strike       NaN
# 4  Glasnow, Tyler  543807   607192  strikeout  swinging_strike       NaN
#
#    spin_rate_deprecated  break_angle_deprecated  break_length_deprecated  \
# ...

# %%
df['bb_type'].unique()
# Out:
# array(['ground_ball', None, 'line_drive', 'popup', 'fly_ball'],
#       dtype=object)
